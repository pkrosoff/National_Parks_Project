# %%
import pymongo
import pandas as pd

park_info_df = pd.read_csv('../data/info_and_atten.csv')
park_info_df
# # splitting, reformatting area types
# parks_data[['AREA_acres','area_KM2']] = parks_data.AREA_km2.str.split("(",expand=True)
# area_acres = parks_data['AREA_acres'].replace({' acres':'',',':''}, regex=True)
# area_acres = area_acres.str.strip().to_frame().astype('float')
# parks_data['area_acres'] = area_acres

# # finding km2 and mi2 with math
# parks_data['area_km2'] = round(parks_data['area_acres']*0.00404686,2)
# parks_data['area_miles2'] = round(parks_data['area_acres']*0.0015625,2)
# parks_data = parks_data.drop(columns=['AREA_km2', 'area_KM2','AREA_acres'])
# parks.data
# Out:
#     Unnamed: 0           park_name park_code          region         state  \
# 0            0              Acadia      ACAD      Northeast          Maine
# 1            1              Arches      ARCH  Intermountain           Utah
# 2            2            Badlands      BADL        Midwest   South Dakota
# 3            3            Big Bend      BIBE  Intermountain          Texas
# 4            4            Biscayne      BISC      Southeast        Florida
# ..         ...                 ...       ...             ...           ...
# 56          56           Wind Cave      WICA        Midwest   South Dakota
# 57          57  Wrangell–St. Elias      WRST          Alaska        Alaska
# 58          58         Yellowstone      YELL  Intermountain        Wyoming
# 59          59            Yosemite      YOSE   Pacific West     California
# 60          60                Zion      ZION  Intermountain           Utah
#
# ...

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# define the database
db = client.national_parks_db

# %%
# define collections
park_info = db.park_info
park_atten = db.park_atten

# %%
# fill database collection park_info
park_info.drop()
for index, row in park_info.iterrows():
    
    post = {
        "park_name": str(row["park_name"]),
        "park_code": str(row["park_code"]),
        "region": str(row["region"]),
        "state": str(row["state"]),
        "est_date": str(row["date_established"]),
        "area_km2": float(row["area_km2"]),
        "area_acres": float(row["area_acres"]),
        "area_miles2": float(row["area_miles2"]),
        "image_url": str(row["img_url"]),
        "description": str(row["description"])
    }
    #Insert data into business collection, post{} by post{}
    park_info.insert_one(post)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-ae8b11ca457f> in <module>
#       1 # fill database collection park_info
#       2 park_info.drop()
# ----> 3 for index, row in park_info.iterrows():
#       4
#       5     post = {
#
# /opt/anaconda3/envs/np_project/lib/python3.6/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3446                         "call the '%s' method on a 'Collection' object it is "
#    3447                         "failing because no such method exists." %
# -> 3448                         self.__name.split(".")[-1])
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'iterrows' method on a 'Collection' object it is failing because no such method exists.

# %%
park_atten.drop()
# fill database collection park_attendence

for index, row in park_info_test.iterrows():
    
    post = {
        "park_name": str(row["park_name"]),
        "park_code": str(row["park_code"]),
        "1904": int(row["1904"]),
        "1905": int(row["1905"]),
        "1906": int(row["1906"]),
        "1907": int(row["1907"]),
        "1908": int(row["1908"]),
        "1909": int(row["1909"]),
        "1910": int(row["1910"]),
        "1911": int(row["1911"]),
        "1912": int(row["1912"]),
        "1913": int(row["1913"]),
        "1914": int(row["1914"]),
        "1915": int(row["1915"]),
        "1916": int(row["1916"]),
        "1917": int(row["1917"]),
        "1918": int(row["1918"]),
        "1919": int(row["1919"]),
        "1920": int(row["1920"]),
        "1921": int(row["1921"]),
        "1922": int(row["1922"]),
        "1923": int(row["1923"]),
        "1924": int(row["1924"]),
        "1925": int(row["1925"]),
        "1926": int(row["1926"]),
        "1927": int(row["1927"]),
        "1928": int(row["1928"]),
        "1929": int(row["1929"]),
        "1930": int(row["1930"]),
        "1931": int(row["1931"]),
        "1932": int(row["1932"]),
        "1933": int(row["1933"]),
        "1934": int(row["1934"]),
        "1935": int(row["1935"]),
        "1936": int(row["1936"]),
        "1937": int(row["1937"]),
        "1938": int(row["1938"]),
        "1939": int(row["1939"]),
        "1940": int(row["1940"]),
        "1941": int(row["1941"]),
        "1942": int(row["1942"]),
        "1943": int(row["1943"]),
        "1944": int(row["1944"]),
        "1945": int(row["1945"]),
        "1946": int(row["1946"]),
        "1947": int(row["1947"]),
        "1948": int(row["1948"]), 
        "1949": int(row["1949"]),
        "1950": int(row["1950"]),
        "1951": int(row["1951"]),
        "1952": int(row["1952"]),
        "1953": int(row["1953"]),
        "1954": int(row["1954"]),
        "1955": int(row["1955"]),
        "1956": int(row["1956"]),
        "1957": int(row["1957"]),
        "1958": int(row["1958"]),
        "1959": int(row["1959"]),
        "1960": int(row["1960"]),
        "1961": int(row["1961"]),
        "1962": int(row["1962"]),
        "1963": int(row["1963"]),
        "1964": int(row["1964"]),
        "1965": int(row["1965"]),
        "1966": int(row["1966"]),
        "1967": int(row["1967"]),
        "1968": int(row["1968"]),
        "1969": int(row["1969"]),
        "1970": int(row["1970"]),
        "1971": int(row["1971"]),
        "1972": int(row["1972"]),
        "1973": int(row["1973"]),
        "1974": int(row["1974"]),
        "1975": int(row["1975"]),
        "1976": int(row["1976"]),
        "1977": int(row["1977"]),
        "1978": int(row["1978"]),
        "1979": int(row["1979"]),
        "1980": int(row["1980"]),
        "1981": int(row["1981"]),
        "1982": int(row["1982"]),
        "1983": int(row["1983"]),
        "1984": int(row["1984"]),
        "1985": int(row["1985"]),
        "1986": int(row["1986"]),
        "1987": int(row["1987"]),
        "1988": int(row["1988"]), 
        "1989": int(row["1989"]),
        "1990": int(row["1990"]),
        "1991": int(row["1991"]),
        "1992": int(row["1992"]),
        "1993": int(row["1993"]),
        "1994": int(row["1994"]),
        "1995": int(row["1995"]),
        "1996": int(row["1996"]),
        "1997": int(row["1997"]),
        "1998": int(row["1998"]), 
        "1999": int(row["1999"]),
        "2000": int(row["2000"]),
        "2001": int(row["2001"]),
        "2002": int(row["2002"]),
        "2003": int(row["2003"]),
        "2004": int(row["2004"]),
        "2005": int(row["2005"]),
        "2006": int(row["2006"]),
        "2007": int(row["2007"]),
        "2008": int(row["2008"]), 
        "2009": int(row["2009"]),
        "2010": int(row["2010"]),
        "2011": int(row["2011"]),
        "2012": int(row["2012"]),
        "2013": int(row["2013"]),
        "2014": int(row["2014"]),
        "2015": int(row["2015"]),
        "2016": int(row["2016"]),
        "2017": int(row["2017"]),
        "2018": int(row["2018"]), 
        "2019": int(row["2019"]),
      
        
#         want to make a loop so I dont have to write all these dates!
#         for i in range(1904,2020,1):
#             i : int(row[i])
    }
    park_atten.insert_one(post)
# park_atten.insert_one(post)
